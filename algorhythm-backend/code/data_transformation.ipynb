# %% [markdown]
# ## Import Datasets

# %%
import pandas as pd

general_df = pd.DataFrame()

# Wanted Song Features:

# ID                    The Spotify ID for the track.
# Name                  The name of the track.
# Artist                The name of the artist.
# Energy-	            A measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
# Tempo-                The speed of a track, measured in beats per minute (BPM).
# Danceability-	        A score describing how suitable a track is for dancing based on tempo, rhythm stability, beat strength and overall regularity.
# Loudness-	            The overall loudness of a track in decibels (dB). Higher values indicate louder tracks overall.
# Liveness-	            The likelihood of a track being performed live. Higher values suggest more audience presence.
# Valence-	            The overall musical positiveness(emotion) of a track. High valence sounds happy; low valence sounds sad or angry.
# Speechiness-	        Measures the presence of spoken words.
# Instrumentalness-	    The likelihood a track contains no vocals. Values closer to 1.0 suggest solely instrumental tracks.
# Mode	                Indicates the modality of the track.
# Key	                The musical key, represented as an integer from 0 to 11, mapping to standard Pitch class notation.
# Duration_ms	        The length of the track in milliseconds.
# Acousticness-	        A confidence measure of whether a track is acoustic(1) or not(0).

df_1 = pd.read_csv('../data/tracks_features.csv') # Taken from: https://www.kaggle.com/datasets/rodolfofigueroa/spotify-12m-songs

# Song Features: ALL

df_2 = pd.read_csv('../data/dataset.csv') # Taken from: https://www.kaggle.com/datasets/maharshipandya/-spotify-tracks-dataset

# Song Features: ALL

df_3 = pd.read_csv('../data/high_popularity_spotify_data.csv') # Taken from: https://www.kaggle.com/datasets/solomonameh/spotify-music-dataset    

# Song Features: ALL

df_4 = pd.read_csv('../data/data.csv') # Taken from: https://www.kaggle.com/datasets/ektanegi/spotifydata-19212020

# Song Features: ALL

# df_5 = pd.read_csv('../data/genres_v2.csv') # Taken from: https://www.kaggle.com/datasets/mrmorj/dataset-of-songs-in-spotify

# Song Features: NO Artist Name

# %% [markdown]
# ## Present Datasets

# %% [markdown]
# ### Dataset 1

# %%
# df_1.head()

# %%
df_1 = df_1.loc[:, ['id', 'name', 'artists', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]
df_1.head()
# Out:
#                        id                   name  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                Testify
# 1  1wsRitfRRtWyEapl0q22o8        Guerrilla Radio
# 2  1hR0fIFK2qRG3f3RF70pb7       Calm Like a Bomb
# 3  2lbASgTSoDO7MTuLAXlTW0              Mic Check
# 4  1MQTmpYOZ6fcMQc56Hdo7T  Sleep Now In the Fire
#
#                         artists  danceability  energy  loudness  speechiness  \
# 0  ['Rage Against The Machine']         0.470   0.978    -5.399       0.0727
# 1  ['Rage Against The Machine']         0.599   0.957    -5.764       0.1880
# 2  ['Rage Against The Machine']         0.315   0.970    -5.424       0.4830
# 3  ['Rage Against The Machine']         0.440   0.967    -5.830       0.2370
# 4  ['Rage Against The Machine']         0.426   0.929    -6.729       0.0701
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0       0.02610          0.000011    0.3560    0.503  117.906
# 1       0.01290          0.000071    0.1550    0.489  103.680
# 2       0.02340          0.000002    0.1220    0.370  149.749
# 3       0.16300          0.000004    0.1210    0.574   96.752
# 4       0.00162          0.105000    0.0789    0.539  127.059

# %% [markdown]
# ### Dataset 2

# %%
# df_2.head()

# %%
df_2 = df_2.rename(columns={'track_id': 'id', 'track_name': 'name'})
df_2 = df_2.loc[:, ['id', 'name', 'artists', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

df_2["artists"] = df_2["artists"].apply(
    lambda x: [artist.strip() for artist in x.split(";")] if isinstance(x, str) else x
)

df_2.head()
# Out:
#                        id                        name  \
# 0  5SuOikwiRyPMVoIQDJUgSV                      Comedy
# 1  4qPNDBW1i3p13qLCt0Ki3A            Ghost - Acoustic
# 2  1iJBSr7s7jYXzM8EGcbK5b              To Begin Again
# 3  6lfxq3CG4xtTiEg7opyCyx  Can't Help Falling In Love
# 4  5vjLSffimiIP26QG5WcN2K                     Hold On
#
#                      artists  danceability  energy  loudness  speechiness  \
# 0              [Gen Hoshino]         0.676  0.4610    -6.746       0.1430
# 1             [Ben Woodward]         0.420  0.1660   -17.235       0.0763
# 2  [Ingrid Michaelson, ZAYN]         0.438  0.3590    -9.734       0.0557
# 3             [Kina Grannis]         0.266  0.0596   -18.515       0.0363
# 4         [Chord Overstreet]         0.618  0.4430    -9.681       0.0526
#
#    acousticness  instrumentalness  liveness  valence    tempo
# 0        0.0322          0.000001    0.3580    0.715   87.917
# 1        0.9240          0.000006    0.1010    0.267   77.489
# 2        0.2100          0.000000    0.1170    0.120   76.332
# 3        0.9050          0.000071    0.1320    0.143  181.740
# 4        0.4690          0.000000    0.0829    0.167  119.949

# %% [markdown]
# ### Dataset 3

# %%
# df_3.head()

# %%
df_3 = df_3.rename(columns={'track_name': 'name', 'track_artist': 'artists'})

df_3 = df_3.loc[:, ['id', 'name', 'artists', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

df_3["artists"] = df_3["artists"].apply(
    lambda x: [artist.strip() for artist in x.split(",")] if isinstance(x, str) else x
)

df_3.head()
# Out:
#                        id                name                  artists  \
# 0  2plbrEY59IikOBgBGLjaoe    Die With A Smile  [Lady Gaga, Bruno Mars]
# 1  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER          [Billie Eilish]
# 2  7ne4VBA60CxGM75vw0EYad      That’s So True          [Gracie Abrams]
# 3  1d7Ptw3qYcfpdLNL5REhtJ               Taste      [Sabrina Carpenter]
# 4  5vNRhkKd0yEAg8suGBpjeY                APT.       [ROSÉ, Bruno Mars]
#
#    danceability  energy  loudness  speechiness  acousticness  \
# 0         0.521   0.592    -7.777       0.0304        0.3080
# 1         0.747   0.507   -10.171       0.0358        0.2000
# 2         0.554   0.808    -4.169       0.0368        0.2140
# 3         0.670   0.910    -4.070       0.0634        0.0939
# 4         0.777   0.783    -4.477       0.2600        0.0283
#
#    instrumentalness  liveness  valence    tempo
# 0            0.0000     0.122    0.535  157.969
# 1            0.0608     0.117    0.438  104.978
# 2            0.0000     0.159    0.372  108.548
# 3            0.0000     0.304    0.786  112.966
# 4            0.0000     0.355    0.939  149.027

# %% [markdown]
# ### Dataset 4

# %%
# df_4.head()

# %%
df_4 = df_4.loc[:, ['id', 'name', 'artists', 'danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']]

df_4.head()
# Out:
#                        id                                           name  \
# 0  6KbQ3uYMLKb5jDxLF7wYDD                    Singende Bataillone 1. Teil
# 1  6KuQTIu1KoTTkLXKrwlLPV       Fantasiestücke, Op. 111: Più tosto lento
# 2  6L63VW0PibdM1HDSBoqnoM                 Chapter 1.18 - Zamek kaniowski
# 3  6M94FkXd15sOAOQYRnWPN8  Bebamos Juntos - Instrumental (Remasterizado)
# 4  6N6tiFZ9vLTSOIxkj8qKrd    Polonaise-Fantaisie in A-Flat Major, Op. 61
#
#                                     artists  danceability  energy  loudness  \
# 0                       ['Carl Woitschach']         0.708  0.1950   -12.428
# 1  ['Robert Schumann', 'Vladimir Horowitz']         0.379  0.0135   -28.454
# 2                   ['Seweryn Goszczyński']         0.749  0.2200   -19.924
# 3                      ['Francisco Canaro']         0.781  0.1300   -14.734
# 4  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210  0.2040   -16.829
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo
# 0       0.0506         0.995             0.563    0.1510   0.7790  118.469
# 1       0.0462         0.994             0.901    0.0763   0.0767   83.972
# 2       0.9290         0.604             0.000    0.1190   0.8800  107.177
# 3       0.0926         0.995             0.887    0.1110   0.7200  108.003
# 4       0.0424         0.990             0.908    0.0980   0.0693   62.149

# %% [markdown]
# ### Dataset Lengths

# %%
print("df_1: ", len(df_1), "entries")
print("df_2: ", len(df_2), "entries")
print("df_3: ", len(df_3), "entries")
print("df_4: ", len(df_4), "entries")
print("")
print("Sum: ", len(df_1) + len(df_2) + len(df_3) + len(df_4), "entries")
# Out:
# df_1:  1204025 entries
# df_2:  114000 entries
# df_3:  1686 entries
# df_4:  169909 entries
#
# Sum:  1489620 entries

# %% [markdown]
# ## Build Dataset for SQLite Database

# %% [markdown]
# ### Remove Duplicates

# %%
general_df = pd.concat([df_1, df_2, df_3, df_4], ignore_index=True)

general_df = general_df.drop_duplicates(subset=['id'], keep='first')

print("Length without duplicates: ", len(general_df), "entries")
# Out:
# Length without duplicates:  1430573 entries

# %% [markdown]
# ### Create URLs for Embeds

# %%
embed_urls = []

for i in general_df["id"]:
    embed_urls.append(f"https://open.spotify.com/embed/track/{i}?utm_source=generator")

# %%
general_df["embed_urls"] = embed_urls

# %%
len(general_df), len(embed_urls)
# Out:
# (1430573, 1430573)

# %%
general_df.columns
# Out:
# Index(['id', 'name', 'artists', 'danceability', 'energy', 'loudness',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'embed_urls'],
#       dtype='object')

# %%
general_df.head(10)
# Out:
#                        id                    name  \
# 0  7lmeHLHBe4nmXzuXc0HDjk                 Testify
# 1  1wsRitfRRtWyEapl0q22o8         Guerrilla Radio
# 2  1hR0fIFK2qRG3f3RF70pb7        Calm Like a Bomb
# 3  2lbASgTSoDO7MTuLAXlTW0               Mic Check
# 4  1MQTmpYOZ6fcMQc56Hdo7T   Sleep Now In the Fire
# 5  2LXPNLSMAauNJfnC58lSqY    Born of a Broken Man
# 6  3moeHk8eIajvUEzVocXukf          Born As Ghosts
# 7  4llunZfVXv3NvUzXVB3VVL                   Maria
# 8  21Mq0NzFoVRvOmLTOnJjng  Voice of the Voiceless
# 9  6s2FgJbnnMwFTpWJZzvb6z    New Millennium Homes
#
#                         artists  danceability  energy  loudness  speechiness  \
# 0  ['Rage Against The Machine']         0.470   0.978    -5.399       0.0727
# 1  ['Rage Against The Machine']         0.599   0.957    -5.764       0.1880
# 2  ['Rage Against The Machine']         0.315   0.970    -5.424       0.4830
# 3  ['Rage Against The Machine']         0.440   0.967    -5.830       0.2370
# 4  ['Rage Against The Machine']         0.426   0.929    -6.729       0.0701
# 5  ['Rage Against The Machine']         0.298   0.848    -5.947       0.0727
# 6  ['Rage Against The Machine']         0.417   0.976    -6.032       0.1750
# 7  ['Rage Against The Machine']         0.277   0.873    -6.571       0.0883
# 8  ['Rage Against The Machine']         0.441   0.882    -7.363       0.0440
# 9  ['Rage Against The Machine']         0.448   0.861    -6.120       0.0676
#
#    acousticness  instrumentalness  liveness  valence    tempo  \
# 0      0.026100          0.000011    0.3560    0.503  117.906
# 1      0.012900          0.000071    0.1550    0.489  103.680
# 2      0.023400          0.000002    0.1220    0.370  149.749
# 3      0.163000          0.000004    0.1210    0.574   96.752
# 4      0.001620          0.105000    0.0789    0.539  127.059
# 5      0.053800          0.001520    0.2010    0.194  148.282
# 6      0.000427          0.000134    0.1070    0.483   90.395
# 7      0.006940          0.000054    0.1880    0.618  172.848
# 8      0.019500          0.006840    0.1500    0.418   83.371
# 9      0.003060          0.000000    0.0987    0.761   92.777
#
#                                           embed_urls
# 0  https://open.spotify.com/embed/track/7lmeHLHBe...
# 1  https://open.spotify.com/embed/track/1wsRitfRR...
# 2  https://open.spotify.com/embed/track/1hR0fIFK2...
# 3  https://open.spotify.com/embed/track/2lbASgTSo...
# 4  https://open.spotify.com/embed/track/1MQTmpYOZ...
# 5  https://open.spotify.com/embed/track/2LXPNLSMA...
# 6  https://open.spotify.com/embed/track/3moeHk8eI...
# 7  https://open.spotify.com/embed/track/4llunZfVX...
# 8  https://open.spotify.com/embed/track/21Mq0NzFo...
# 9  https://open.spotify.com/embed/track/6s2FgJbnn...

# %%
general_df.to_csv('../data/all_data.csv', index=False)

# %%
len(general_df)
# Out:
# 1430573

# %%
# get min value from column tempo

min_tempo = general_df['loudness'].min()

min_tempo
# Out:
# np.float64(-60.0)
